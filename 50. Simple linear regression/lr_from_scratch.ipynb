# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("placement.csv")

# %%
df.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
X = df.iloc[:,0].values # values for array
y = df.iloc[:,1].values

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=23)

# %%
X_train.shape
# Out:
# (160,)

# %%
X_train.shape[0]
# Out:
# 160

# %%
X_test
# Out:
# array([7.78, 7.36, 7.35, 8.99, 7.73, 7.39, 5.98, 7.48, 7.63, 7.32, 6.31,
#        6.97, 6.07, 6.1 , 7.28, 6.22, 6.47, 6.53, 7.9 , 7.91, 7.04, 8.37,
#        8.93, 7.12, 5.84, 6.71, 6.92, 7.08, 9.26, 5.58, 6.37, 6.94, 8.13,
#        6.33, 6.76, 5.13, 6.09, 8.01, 7.28, 6.66])

# %%
class AJLR:

    def __init__(self):
        self.m = None
        self.b = None

    def fit(self, X_train, y_train):

        num = 0
        den = 0
        
        for i in range(X_train.shape[0]):
            num = num + (X_train[i] - X_train.mean()) * (y_train[i] - y_train.mean())
            den = den + (X_train[i] - X_train.mean()) * (X_train[i] - X_train.mean()) 
            
            self.m = num/den
            self.b = (y_train.mean() - self.m * X_train.mean())

        return self.b, self.m
        
    def predict(self, X_test):
        
        return (self.m * X_test) + self.b

# %%
lr = AJLR()

# %%
lr.fit(X_train, y_train)
# Out:
# (-0.9456246876851346, 0.5631424586282687)

# %%
lr.predict(X_test[0])
# Out:
# 3.435623640442796

# %%
X_test[0]
# Out:
# 7.78
