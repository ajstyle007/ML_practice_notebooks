# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("placement.csv")

# %%
df.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
df.shape
# Out:
# (200, 2)

# %%
plt.scatter(df["cgpa"], df["package"])
plt.xlabel("cgpa")
plt.ylabel("package")
plt.title("scatter plot")
plt.show()

# %%
X = df.iloc[:,0:1]
y = df.iloc[:,1]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=23)

# %%
X_train.shape
# Out:
# (160, 1)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
lr.predict(X_test)
# Out:
# array([3.43562364, 3.19910381, 3.19347238, 4.11702602, 3.40746652,
#        3.21599808, 2.42196721, 3.2666809 , 3.35115227, 3.17657811,
#        2.60780423, 2.97947825, 2.47265004, 2.48954431, 3.15405241,
#        2.5571214 , 2.69790702, 2.73169557, 3.50320074, 3.50883216,
#        3.01889822, 3.76787769, 4.08323747, 3.06394962, 2.34312727,
#        2.83306121, 2.95132113, 3.04142392, 4.26907448, 2.19671023,
#        2.64159277, 2.96258398, 3.6327235 , 2.61906708, 2.86121833,
#        1.94329613, 2.48391289, 3.56514641, 3.15405241, 2.80490409])

# %%
plt.scatter(df["cgpa"], df["package"])
plt.plot(X_train, lr.predict(X_train), color = "red")
plt.xlabel("cgpa")
plt.ylabel("package")
plt.title("scatter plot")
plt.show()

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
y_pred = lr.predict(X_test)

# %%
print("MAE:", mean_absolute_error(y_test, y_pred))
# Out:
# MAE: 0.2650147048100542

# %%
print("MSE:", mean_squared_error(y_test, y_pred))
# Out:
# MSE: 0.112913808980138

# %%
print("RMSE:", np.sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# RMSE: 0.3360265004134912

# %%
print("R2 score:", r2_score(y_test, y_pred))
# Out:
# R2 score: 0.7309298089286885

# %%
r2 = r2_score(y_test, y_pred)

# %%
X_test.shape
# Out:
# (40, 1)

# %%
print("Adjusted R2 score:", 1 - ((1-r2)*(40-1))/(40-1-1))
# Out:
# Adjusted R2 score: 0.7238490144268119

# %%
new_df = df.copy()
new_df["random_feature"] = np.random.random(200)

new_df = new_df[["cgpa", "random_feature", "package"]]
new_df.head()
# Out:
#    cgpa  random_feature  package
# 0  6.89        0.504631     3.26
# 1  5.12        0.053470     1.98
# 2  7.82        0.185704     3.25
# 3  7.42        0.501369     3.67
# 4  6.94        0.797684     3.57

# %%
plt.scatter(new_df["random_feature"], new_df["package"])
plt.xlabel("cgpa")
plt.ylabel("package (lpa)")
plt.title("scatter plot")
plt.show()

# %%
X = new_df.iloc[:,0:2]
y = new_df.iloc[:,2]

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2, random_state=23)

# %%
X_train.shape
# Out:
# (160, 2)

# %%
lr = LinearRegression()

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_test)
y_pred
# Out:
# array([3.43361236, 3.20258008, 3.20406089, 4.13136581, 3.42906535,
#        3.21398926, 2.43323839, 3.28754832, 3.33258626, 3.19617406,
#        2.62084045, 2.98914088, 2.48869014, 2.49988322, 3.15033484,
#        2.55760035, 2.68028063, 2.74030078, 3.52673917, 3.51496476,
#        3.03975688, 3.78867047, 4.10014701, 3.05187534, 2.34997675,
#        2.83862961, 2.94698704, 3.04771552, 4.25322323, 2.20119424,
#        2.62350959, 2.95641766, 3.63608379, 2.63620899, 2.85617908,
#        1.9389117 , 2.46758351, 3.57535361, 3.15924789, 2.82675095])

# %%
print("R2 score: ", r2_score(y_test, y_pred))
r2 = r2_score(y_test, y_pred)
# Out:
# R2 score:  0.7355004317134162

# %%
print("Adjusted R2 score:", 1 - ((1-r2)*(40-1))/(40-1-1))
# Out:
# Adjusted R2 score: 0.728539916758506

# %%
new_df1 = df.copy()
new_df1["iq"] = new_df1["package"] + (np.random.randint(-12,12, 200)/10)

new_df1 = new_df1[["cgpa", "iq", "package"]]
new_df1.head()
# Out:
#    cgpa    iq  package
# 0  6.89  2.76     3.26
# 1  5.12  2.98     1.98
# 2  7.82  4.35     3.25
# 3  7.42  3.07     3.67
# 4  6.94  4.37     3.57

# %%
plt.scatter(new_df1["iq"], new_df1["package"])
plt.xlabel("cgpa")
plt.ylabel("package (lpa)")
plt.title("scatter plot")
plt.show()

# %%
X = new_df1.iloc[:,0:2]
y = new_df1.iloc[:,2]

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2, random_state=23)

# %%
lr = LinearRegression()

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_test)
y_pred
# Out:
# array([3.39698494, 3.29363649, 2.9795056 , 4.03719088, 3.37441696,
#        3.26602561, 2.66684118, 3.36151685, 3.39590752, 3.32065298,
#        2.80403219, 3.14112152, 2.39784624, 2.49760956, 3.06548662,
#        2.71441976, 2.62542051, 2.65446168, 3.44722887, 3.2851762 ,
#        3.00027161, 3.89647981, 4.05126098, 2.87765252, 2.29795276,
#        3.12958662, 2.84616871, 2.94973988, 4.35305865, 2.10025556,
#        2.6018402 , 2.75525614, 3.68821378, 2.52107852, 2.86997175,
#        2.03431601, 2.29909526, 3.39105985, 2.90479917, 2.6367139 ])

# %%
print("R2 score: ", r2_score(y_test, y_pred))
r2 = r2_score(y_test, y_pred)
# Out:
# R2 score:  0.731316214693843

# %%
print("Adjusted R2 score:", 1 - ((1-r2)*(40-1))/(40-1-1))
# Out:
# Adjusted R2 score: 0.7242455887647337
