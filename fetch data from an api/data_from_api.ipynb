# %%
import pandas as pd

# %%
import requests

url = "https://api.themoviedb.org/3/movie/top_rated?api_key=3be03d7c94c03ea51a93cf7d46661d07&language=en-US&page=1%27"

response = requests.get(url)

print(response.text)
# Out:
# {"page":1,"results":[{"adult":false,"backdrop_path":"/kXfqcdQKsToO0OUXHcrrNCHDBzO.jpg","genre_ids":[18,80],"id":278,"original_language":"en","original_title":"The Shawshank Redemption","overview":"Framed in the 1940s for the double murder of his wife and her lover, upstanding banker Andy Dufresne begins a new life at the Shawshank prison, where he puts his accounting skills to work for an amoral warden. During his long stretch in prison, Dufresne comes to be admired by the other inmates -- including an older prisoner named Red -- for his integrity and unquenchable sense of hope.","popularity":134.724,"poster_path":"/q6y0Go1tsGEsmtFryDOJo3dEmqu.jpg","release_date":"1994-09-23","title":"The Shawshank Redemption","video":false,"vote_average":8.71,"vote_count":25327},{"adult":false,"backdrop_path":"/rSPw7tgCH9c6NqICZef4kZjFOQ5.jpg","genre_ids":[18,80],"id":238,"original_language":"en","original_title":"The Godfather","overview":"Spanning the years 1945 to 1955, a chronicle of the fiction
# ...

# %%
response.json()["results"]
# Out:
# [{'adult': False,
#   'backdrop_path': '/kXfqcdQKsToO0OUXHcrrNCHDBzO.jpg',
#   'genre_ids': [18, 80],
#   'id': 278,
#   'original_language': 'en',
#   'original_title': 'The Shawshank Redemption',
#   'overview': 'Framed in the 1940s for the double murder of his wife and her lover, upstanding banker Andy Dufresne begins a new life at the Shawshank prison, where he puts his accounting skills to work for an amoral warden. During his long stretch in prison, Dufresne comes to be admired by the other inmates -- including an older prisoner named Red -- for his integrity and unquenchable sense of hope.',
#   'popularity': 134.724,
#   'poster_path': '/q6y0Go1tsGEsmtFryDOJo3dEmqu.jpg',
#   'release_date': '1994-09-23',
#   'title': 'The Shawshank Redemption',
#   'video': False,
#   'vote_average': 8.71,
#   'vote_count': 25327},
#  {'adult': False,
#   'backdrop_path': '/rSPw7tgCH9c6NqICZef4kZjFOQ5.jpg',
#   'genre_ids': [18, 80],
#   'id': 238,
#   'original_language': 'en',
# ...

# %%
pd.DataFrame(response.json()["results"])
# Out:
#     adult                     backdrop_path         genre_ids      id  \
# 0   False  /kXfqcdQKsToO0OUXHcrrNCHDBzO.jpg          [18, 80]     278
# 1   False  /rSPw7tgCH9c6NqICZef4kZjFOQ5.jpg          [18, 80]     238
# 2   False  /kGzFbGhp99zva6oZODW5atUtnqi.jpg          [18, 80]     240
# 3   False  /3f92DMBTFqr3wgXpfxzrb0qv8nG.jpg   [18, 36, 10752]     424
# 4   False  /90ez6ArvpO8bvpyIngBuwXOqJm5.jpg   [35, 18, 10749]   19404
# 5   False  /qqHQsStV6exghCM7zbObuYBiYxw.jpg              [18]     389
# 6   False  /mSDsSDwaP3E7dEfUPWy4J0djt4O.jpg   [16, 10751, 14]     129
# 7   False  /nMKdUUepR0i5zn0y1T4CsSB5chy.jpg  [18, 28, 80, 53]     155
# 8   False  /hiKmpZMGZsrkA3cdce8a7Dpos1j.jpg      [35, 53, 18]  496243
# 9   False  /l6hQWH9eDksNJNiXWYRkWqikOdu.jpg      [14, 18, 80]     497
# 10  False  /dIWwZW7dJJtqC6CgWzYkNVKIUm8.jpg   [10749, 16, 18]  372058
# 11  False  /suaEOtk1N1sgg2MTM7oZd2cfVp3.jpg          [53, 80]     680
# ...

# %%
df = pd.DataFrame(response.json()["results"])[["id", "title", "overview", "popularity", "release_date", "vote_average", "vote_count"]]

# %%
df.head()
# Out:
#       id                        title  \
# 0    278     The Shawshank Redemption
# 1    238                The Godfather
# 2    240        The Godfather Part II
# 3    424             Schindler's List
# 4  19404  Dilwale Dulhania Le Jayenge
#
#                                             overview  popularity release_date  \
# 0  Framed in the 1940s for the double murder of h...     134.724   1994-09-23
# 1  Spanning the years 1945 to 1955, a chronicle o...     128.822   1972-03-14
# 2  In the continuing saga of the Corleone crime f...      84.795   1974-12-20
# 3  The true story of how businessman Oskar Schind...      73.187   1993-12-15
# 4  Raj is a rich, carefree, happy-go-lucky second...      34.162   1995-10-20
#
#    vote_average  vote_count
# 0         8.710       25327
# 1         8.708       19293
# 2         8.590       11636
# 3         8.572       14994
# 4         8.547        4317

# %%
df1 = pd.DataFrame()
df1
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for i in range(1, 455):
    requests.get("https://api.themoviedb.org/3/movie/top_rated?api_key=3be03d7c94c03ea51a93cf7d46661d07&language=en-US&page={}".format(i))
    temp_df = pd.DataFrame(response.json()["results"])[["id", "title", "overview", "popularity", "release_date", "vote_average", "vote_count"]]
    df1 = df1._append(temp_df, ignore_index=True)

# %%
df1.to_csv("movies.csv", index=False)

# %%
movies = pd.read_csv("movies.csv")

# %%
movies.shape
# Out:
# (9080, 7)

# %%
movies
# Out:
#          id                        title  \
# 0       278     The Shawshank Redemption
# 1       238                The Godfather
# 2       240        The Godfather Part II
# 3       424             Schindler's List
# 4     19404  Dilwale Dulhania Le Jayenge
# ...     ...                          ...
# 9075    769                   GoodFellas
# 9076    346                Seven Samurai
# 9077    637            Life Is Beautiful
# 9078  12477       Grave of the Fireflies
# 9079  11216              Cinema Paradiso
#
#                                                overview  popularity  \
# 0     Framed in the 1940s for the double murder of h...     134.724
# 1     Spanning the years 1945 to 1955, a chronicle o...     128.822
# 2     In the continuing saga of the Corleone crime f...      84.795
# 3     The true story of how businessman Oskar Schind...      73.187
# 4     Raj is a rich, carefree, happy-go-lucky second...      34.162
# ...

# %%
import requests

url = "https://free-nba.p.rapidapi.com/players"

querystring = {"page":"0","per_page":"25"}

headers = {
	"X-RapidAPI-Key": "8628bf8a66msh65401b0d048f118p13ed56jsn7adef0368a0a",
	"X-RapidAPI-Host": "free-nba.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'data': [{'id': 14, 'first_name': 'Ike', 'height_feet': None, 'height_inches': None, 'last_name': 'Anigbogu', 'position': 'C', 'team': {'id': 12, 'abbreviation': 'IND', 'city': 'Indiana', 'conference': 'East', 'division': 'Central', 'full_name': 'Indiana Pacers', 'name': 'Pacers'}, 'weight_pounds': None}, {'id': 25, 'first_name': 'Ron', 'height_feet': None, 'height_inches': None, 'last_name': 'Baker', 'position': 'G', 'team': {'id': 20, 'abbreviation': 'NYK', 'city': 'New York', 'conference': 'East', 'division': 'Atlantic', 'full_name': 'New York Knicks', 'name': 'Knicks'}, 'weight_pounds': None}, {'id': 47, 'first_name': 'Jabari', 'height_feet': None, 'height_inches': None, 'last_name': 'Bird', 'position': 'G', 'team': {'id': 2, 'abbreviation': 'BOS', 'city': 'Boston', 'conference': 'East', 'division': 'Atlantic', 'full_name': 'Boston Celtics', 'name': 'Celtics'}, 'weight_pounds': None}, {'id': 67, 'first_name': 'MarShon', 'height_feet': None, 'height_inches': None, 'last_name': 'B
# ...

# %%
response.json()["data"]
# Out:
# [{'id': 14,
#   'first_name': 'Ike',
#   'height_feet': None,
#   'height_inches': None,
#   'last_name': 'Anigbogu',
#   'position': 'C',
#   'team': {'id': 12,
#    'abbreviation': 'IND',
#    'city': 'Indiana',
#    'conference': 'East',
#    'division': 'Central',
#    'full_name': 'Indiana Pacers',
#    'name': 'Pacers'},
#   'weight_pounds': None},
#  {'id': 25,
#   'first_name': 'Ron',
#   'height_feet': None,
#   'height_inches': None,
#   'last_name': 'Baker',
#   'position': 'G',
#   'team': {'id': 20,
#    'abbreviation': 'NYK',
#    'city': 'New York',
#    'conference': 'East',
#    'division': 'Atlantic',
#    'full_name': 'New York Knicks',
#    'name': 'Knicks'},
#   'weight_pounds': None},
#  {'id': 47,
#   'first_name': 'Jabari',
#   'height_feet': None,
#   'height_inches': None,
#   'last_name': 'Bird',
#   'position': 'G',
#   'team': {'id': 2,
#    'abbreviation': 'BOS',
#    'city': 'Boston',
#    'conference': 'East',
#    'division': 'Atlantic',
# ...

# %%
df2 = pd.DataFrame(response.json()["data"])

# %%
df2.to_csv("nba.csv",index = False)

# %%
pd.read_csv("nba.csv")
# Out:
#       id first_name  height_feet  height_inches   last_name position  \
# 0     14        Ike          NaN            NaN    Anigbogu        C
# 1     25        Ron          NaN            NaN       Baker        G
# 2     47     Jabari          NaN            NaN        Bird        G
# 3     67    MarShon          NaN            NaN      Brooks        G
# 4     71    Lorenzo          NaN            NaN       Brown        G
# 5     90       Omri          NaN            NaN      Casspi        F
# 6      1       Alex          6.0            6.0     Abrines        G
# 7    119      Tyler          NaN            NaN       Davis        C
# 8    149     Keenan          NaN            NaN       Evans        G
# 9    179     Marcin          NaN            NaN      Gortat        C
# 10  1593     Andrew          NaN            NaN       Bogut        F
# 11   241       Amir          6.0            9.0     Johnson      C-F
# 12   392    Malachi          NaN            NaN  Richardson        G
# ...

# %%
df3 = pd.DataFrame()
df3
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for i in range(1, 26):
    url = "https://free-nba.p.rapidapi.com/players"

    querystring = {"page":{}.format(i),"per_page":"25"}

    headers = {
    	"X-RapidAPI-Key": "8628bf8a66msh65401b0d048f118p13ed56jsn7adef0368a0a",
    	"X-RapidAPI-Host": "free-nba.p.rapidapi.com"
    }

    response = requests.get(url, headers=headers, params=querystring)
    temp_df = pd.DataFrame(response.json()["data"])
    df3 = df3._append(temp_df, ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[25], line 4
#       1 for i in range(1, 26):
#       2     url = "https://free-nba.p.rapidapi.com/players"
# ----> 4     querystring = {"page":{}.format(i),"per_page":"25"}
#       6     headers = {
#       7     	"X-RapidAPI-Key": "8628bf8a66msh65401b0d048f118p13ed56jsn7adef0368a0a",
#       8     	"X-RapidAPI-Host": "free-nba.p.rapidapi.com"
#       9     }
#      11     response = requests.get(url, headers=headers, params=querystring)
#
# AttributeError: 'dict' object has no attribute 'format'
