# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_regression

# %%
X, y = make_regression(n_features=1, n_informative=1, n_samples=100, n_targets=1, noise= 20)

# %%
plt.scatter(X, y)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X, y)
# Out:
# LinearRegression()

# %%
print(lr.coef_, lr.intercept_)
# Out:
# [30.3136651] -0.6012819929827584

# %%
m = 30.31

# %%
class GDreg:

    def __init__(self, ler_rate, epochs):
        self.m = m
        self.b = -120
        self.ler_rate = ler_rate
        self.epochs = epochs

    def fit(self, X, y):
        for i in range(self.epochs):  # we have to find the "b" using gradient descent.
            loss_slope = -2 * np.sum(y - (self.m * X.ravel()) - self.b)
            self.b = self.b - (self.ler_rate * loss_slope)
            print(loss_slope, self.b)
        print(self.b)

    def predict(self, y):
        pass

# %%
gd = GDreg(0.001, 100)

# %%
gd.fit(X, y)
# Out:
# -23879.62894058622 -96.12037105941378
# -19103.70315246898 -77.0166679069448
# -15282.962521975182 -61.733705384969625
# -12226.370017580146 -49.50733536738948
# -9781.096014064116 -39.72623935332536
# -7824.876811251292 -31.901362542074068
# -6259.901449001035 -25.641461093073033
# -5007.921159200828 -20.633539933872207
# -4006.336927360662 -16.627203006511543
# -3205.0695418885293 -13.422133464623013
# -2564.055633510823 -10.85807783111219
# -2051.2445068086586 -8.806833324303533
# -1640.9956054469267 -7.165837718856606
# -1312.7964843575419 -5.853041234499064
# -1050.2371874860332 -4.802804047013031
# -840.1897499888266 -3.962614297024204
# -672.1517999910612 -3.290462497033143
# -537.7214399928492 -2.7527410570402937
# -430.17715199427926 -2.3225639050460143
# -344.1417215954234 -1.9784221834505908
# -275.3133772763386 -1.7031088061742523
# -220.2507018210709 -1.4828581043531814
# -176.2005614568568 -1.3066575428963247
# -140.96044916548544 -1.1656970937308393
# ...

# %%
# ans is -732037936232183.4 because of the value of the learning rate => 0.1
# for the learning rate => 0.01 we stuck in a loop after few epochs
# and final for the values of learning rate => 0.01 and epochs => 100 the value converges
